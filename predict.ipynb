# %%
import pickle
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score , classification_report

# %%
class_mapper ={
    
    
       2: 'True Positive' ,
       1: 'False Positive',
       0: 'Benign Positive'
    
}

# %%
model_path = r'./best_decision_tree_model.pkl'

# Load the model from the pickle file
with open(model_path, 'rb') as file:
    model = pickle.load(file)
model
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=50, max_features='sqrt',
#                        min_samples_leaf=5, random_state=42)

# %%
data = pd.read_csv(r'./test_data.csv')
data.head(2)
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0  0.811065  1.297831 -0.475394 -0.703252 -0.321938  1.036414
# 1           1  1.125117 -0.465577  0.198132  0.494561 -1.222142 -0.242079
#
#           6         7         8  ...        26        27       28        29  \
# 0 -0.188338  0.541679  1.434189  ...  0.337131  0.314873  0.02729  0.143503
# 1 -0.242067 -2.082191 -0.256344  ...  0.337131  0.314873  0.02729 -6.998030
#
#          30        31        32        33        34  IncidentGrade
# 0  0.143616  0.304288  0.276908  0.276735 -1.537973              0
# 1 -6.976374  0.304288  0.276908  0.276735  0.650207              0
#
# [2 rows x 37 columns]

# %%
data.drop(columns=['Unnamed: 0' , 'Usage'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data.drop(columns=['Unnamed: 0' , 'Usage'],axis=1,inplace=True)
#
# File c:\CyberThreatsClassifier\env\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
data2=data['IncidentGrade']

# %%
data.drop(columns=['IncidentGrade'],axis=1,inplace=True)

# %%
pred = model.predict(data)
pred
# Out:
# array([2, 1, 0, ..., 1, 1, 1])

# %%
dec = [class_mapper[x] for x in pred]
dec
# Out:
# ['True Positive',
#  'False Positive',
#  'Benign Positive',
#  'False Positive',
#  'False Positive',
#  'True Positive',
#  'False Positive',
#  'Benign Positive',
#  'Benign Positive',
#  'True Positive',
#  'False Positive',
#  'False Positive',
#  'Benign Positive',
#  'False Positive',
#  'Benign Positive',
#  'True Positive',
#  'Benign Positive',
#  'True Positive',
#  'False Positive',
#  'False Positive',
#  'False Positive',
#  'False Positive',
#  'Benign Positive',
#  'Benign Positive',
#  'Benign Positive',
#  'True Positive',
#  'False Positive',
#  'True Positive',
#  'True Positive',
#  'Benign Positive',
#  'False Positive',
#  'True Positive',
#  'False Positive',
#  'False Positive',
#  'Benign Positive',
#  'False Positive',
#  'False Positive',
#  'Benign Positive',
#  'False Positive',
#  'Benign Positive',
#  'Benign Positive',
#  'Benign Positive',
#  'False Positive',
#  'False Positive',
#  'False Positive',
#  'True Positive',
#  'False Positive',
# ...

# %%
data2
# Out:
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0
#           ..
# 4147987    0
# 4147988    0
# 4147989    1
# 4147990    0
# 4147991    2
# Name: IncidentGrade, Length: 4147992, dtype: int64

# %%
model.classes_
# Out:
# array([0, 1, 2])

# %%
acc= accuracy_score(pred , data2)
acc
# Out:
# 0.45703945427088577
